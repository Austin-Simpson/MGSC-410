# %%
from functions import cleanDF
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Read in the data
mergedDF = pd.read_csv('../data/mergedClean.csv')
appDF = pd.read_csv('../data/Original_App_activity.csv')
subscriberDF = pd.read_csv('../data/subscriber_USD.csv')

mergedDF = cleanDF(mergedDF)
appDF = cleanDF(appDF)
subscriberDF = cleanDF(subscriberDF)


appDF_start = appDF.copy()
subscriberDF_start = subscriberDF.copy()
fullDF_start = mergedDF.copy()
print(mergedDF.dtypes)
mergedDF.head()
# Out:
# Unnamed: 0                          int64
# ID                                  int64
# Language                         category
# Subscription Type                category
# Subscription Event Type          category
# Purchase Store                   category
# Purchase Amount                   float64
# Currency                         category
# Subscription Start Date    datetime64[ns]
# Subscription Expiration    datetime64[ns]
# Demo User                            bool
# Free Trial User                      bool
# Free Trial Start Date      datetime64[ns]
# Free Trial Expiration      datetime64[ns]
# Auto Renew                           bool
# Country                          category
# User Type                        category
# Lead Platform                    category
# Email Subscriber                     bool
# Push Notifications                   bool
# Send Count                          int64
# Open Count                          int64
# Click Count                         int64
# Unique Open Count                   int64
# Unique Click Count                  int64
# App Session Platform             category
# App Activity Type                category
# App Session Date           datetime64[ns]
# dtype: object
#    Unnamed: 0  ID Language Subscription Type Subscription Event Type  \
# 0           0   1      POR           Limited        INITIAL_PURCHASE
# 1           1   1      POR           Limited        INITIAL_PURCHASE
# 2           2   1      POR           Limited        INITIAL_PURCHASE
# 3           3   1      POR           Limited        INITIAL_PURCHASE
# 4           4   1      POR           Limited        INITIAL_PURCHASE
#
#   Purchase Store  Purchase Amount Currency Subscription Start Date  \
# 0            App              NaN      NaN              2018-12-28
# 1            App              NaN      NaN              2018-12-28
# 2            App              NaN      NaN              2018-12-28
# 3            App              NaN      NaN              2018-12-28
# 4            App              NaN      NaN              2018-12-28
#
#   Subscription Expiration  Demo User  Free Trial User Free Trial Start Date  \
# 0              2019-06-28       True             True                   NaT
# 1              2019-06-28       True             True                   NaT
# 2              2019-06-28       True             True                   NaT
# 3              2019-06-28       True             True                   NaT
# 4              2019-06-28       True             True                   NaT
#
#   Free Trial Expiration  Auto Renew Country User Type Lead Platform  \
# 0                   NaT       False     NaN  Consumer           App
# 1                   NaT       False     NaN  Consumer           App
# 2                   NaT       False     NaN  Consumer           App
# 3                   NaT       False     NaN  Consumer           App
# 4                   NaT       False     NaN  Consumer           App
#
#    Email Subscriber  Push Notifications  Send Count  Open Count  Click Count  \
# 0              True                True          63           7            0
# 1              True                True          63           7            0
# 2              True                True          63           7            0
# 3              True                True          63           7            0
# 4              True                True          63           7            0
#
#    Unique Open Count  Unique Click Count App Session Platform  \
# 0                  6                   0                  ios
# 1                  6                   0                  ios
# 2                  6                   0                  ios
# 3                  6                   0                  ios
# 4                  6                   0                  ios
#
#   App Activity Type App Session Date
# 0        App Launch       2019-03-20
# 1         Completed       2019-04-17
# 2        App Launch       2019-04-05
# 3        App Launch       2019-04-16
# 4         Completed       2019-03-29
